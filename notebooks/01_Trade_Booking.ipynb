# %% [markdown]
# # Enterprise Interest Rate Swap Analytics Platform
#
# # Notebook 1
#
# ## Trade Booking and Product Representation
#
# ---
#
# ## Objective
#
# An Interest Rate Swap cannot be priced, risk-managed or reported until it has been represented as a structured software object.
#
# The purpose of this notebook is to construct that representation.
#
# The implementation developed here will serve as the foundation for every subsequent notebook in this project. Pricing, market risk, counterparty risk, regulatory capital and reporting components will all consume the same trade object.
#
# The emphasis of this notebook is not valuation. The emphasis is the transformation of a financial agreement into a reliable and reusable software representation.

# %% [markdown]
# # Learning Objectives
#
# After completing this notebook, the reader should be able to:
#
# - Explain the role of trade booking within the trade lifecycle.
# - Distinguish between a legal agreement and its software representation.
# - Identify the minimum information required to represent an Interest Rate Swap.
# - Design a reusable trade object suitable for downstream analytics.
# - Validate trade information before it enters pricing and risk systems.

# %% [markdown]
# # Position within the Trade Lifecycle
#
# An executed transaction passes through several processing stages before it contributes to valuation, risk measurement or financial reporting.
#
# ```
# Client Agreement
#         │
#         ▼
# Trade Capture
#         │
#         ▼
# Product Representation
#         │
#         ▼
# Market Data Association
#         │
#         ▼
# Pricing
#         │
#         ▼
# Risk Measurement
#         │
#         ▼
# Portfolio Aggregation
#         │
#         ▼
# Reporting
# ```
#
# This notebook focuses exclusively on the first two stages.
#
# Every downstream calculation depends on the quality and consistency of the trade representation established during trade capture.

# %% [markdown]
# # The Trade as a Software Object
#
# An Interest Rate Swap is often introduced as a pricing problem.
#
# Within a production environment, it is first a business object.
#
# The object encapsulates the contractual characteristics of the transaction together with the information required by downstream systems.
#
# Typical attributes include:
#
# - economic terms
# - contractual dates
# - counterparties
# - settlement conventions
# - lifecycle state
# - ownership information
# - validation status
#
# As the trade progresses through its lifecycle, additional information is associated with the object without changing its economic identity.
#
# This representation enables pricing, market risk, finance, operations and reporting systems to reference a common source of truth.

# %% [markdown]
# # From Agreement to Product Representation
#
# A financial agreement is initially expressed as legal language describing the obligations of two counterparties.
#
# Software systems cannot operate directly on contractual text.
#
# Each contractual term must therefore be translated into structured fields with clearly defined meaning and data types.
#
# This structured representation is referred to as the trade object.
#
# The trade object provides a standardized interface through which pricing engines, market risk models, reporting systems and operational workflows access transaction information.

# %% [markdown]
# # Information Required for Trade Capture
#
# Different functions within an investment bank depend on different attributes of the same transaction.
#
# | Category | Representative Fields |
# |----------|-----------------------|
# | Identification | Trade ID, Portfolio, Desk |
# | Counterparty | Legal Entity, Counterparty |
# | Economics | Currency, Notional, Fixed Rate |
# | Floating Leg | Reference Index, Spread |
# | Dates | Effective Date, Maturity Date |
# | Cashflow Rules | Payment Frequency, Day Count Convention |
# | Operations | Booking Status, Trade Version |
# | Governance | Source System, Audit Information |
#
# Each attribute exists because at least one downstream process depends upon it.
#
# Removing or incorrectly populating a single field may produce incorrect valuation, inaccurate risk measures or operational failures.

# %% [markdown]
# # System Perspective
#
# The trade object is shared across multiple analytical and operational systems.
#
# ```
#                     Interest Rate Swap
#                             │
#         ┌───────────────────┼───────────────────┐
#         │                   │                   │
#         ▼                   ▼                   ▼
#    Pricing Engine      Risk Engine       Reporting
#
#         │                   │                   │
#         ▼                   ▼                   ▼
#  Present Value          Greeks          Trade Reports
#
#         │
#         ▼
#  Portfolio Risk
#
#         │
#         ▼
#  Capital & XVA
# ```
#
# Although each system performs a different function, they all consume the same underlying trade representation.
#
# Consistency of the trade object is therefore essential for maintaining agreement across valuation, risk and reporting processes.

# %% [markdown]
# # Importance of Accurate Trade Capture
#
# Incorrect trade capture can propagate through every downstream calculation.
#
# Consider a swap intended to exchange coupons every six months.
#
# If the payment frequency is mistakenly recorded as annual, pricing models, sensitivity calculations and portfolio reports may all execute successfully while producing incorrect results.
#
# Such failures are often difficult to detect because the computational models themselves behave correctly.
#
# The underlying issue originates from inaccurate trade representation rather than incorrect mathematics.
#
# For this reason, validation forms an integral part of trade booking.

# %% [markdown]
# # Design of the Trade Object
#
# The implementation developed in this notebook intentionally focuses on the minimum set of attributes required for subsequent notebooks.
#
# The initial trade object contains:
#
# - Trade Identifier
# - Counterparty
# - Currency
# - Notional
# - Fixed Rate
# - Floating Reference Index
# - Direction
# - Effective Date
# - Maturity Date
# - Payment Frequency
# - Day Count Convention
# - Trade Status
#
# Additional attributes will be incorporated as pricing, market risk, counterparty risk and reporting functionality are introduced.

# %% [markdown]
# # Design Principles
#
# The implementation follows four engineering principles.
#
# ### Single Responsibility
#
# The trade object represents the characteristics of a financial transaction.
#
# Pricing, risk calculations and reporting remain separate responsibilities.
#
# ### Reusability
#
# The same trade representation should be usable by every downstream component without modification.
#
# ### Readability
#
# Business terminology should be reflected directly in the attribute names wherever practical.
#
# ### Extensibility
#
# The design should accommodate additional information, including collateral agreements, lifecycle events and regulatory attributes, without requiring structural redesign.

# %% [markdown]
# # Transition to Implementation
#
# The business requirements have now been translated into a software design.
#
# The next section implements the Interest Rate Swap trade object in Python using a structure that can be reused throughout the remainder of the project.

# %% [markdown]
# # Software Design Considerations
#
# Software used within financial institutions must satisfy requirements beyond computational correctness.
#
# A trade representation should exhibit the following characteristics:
#
# - **Consistency**: Every system should interpret the transaction identically.
# - **Maintainability**: Business attributes should be easy to understand and modify.
# - **Validation**: Invalid trade information should be detected before downstream processing.
# - **Extensibility**: Additional attributes should be incorporated without redesigning the entire structure.
# - **Reusability**: The same representation should support pricing, risk analytics, reporting and regulatory calculations.
#
# These principles reduce operational risk while improving the maintainability of analytical systems.

# %% [markdown]
# # Modelling the Trade
#
# From a software perspective, an Interest Rate Swap can be viewed as a collection of related business attributes.
#
# The following conceptual model illustrates the information maintained by the trade object.
#
# ```
#                     InterestRateSwap
#     ┌─────────────────────────────────────────────┐
#     │ Trade Identifier                            │
#     │ Counterparty                                │
#     │ Currency                                    │
#     │ Notional                                    │
#     │ Fixed Rate                                  │
#     │ Floating Reference Index                    │
#     │ Pay / Receive Direction                     │
#     │ Effective Date                              │
#     │ Maturity Date                               │
#     │ Payment Frequency                           │
#     │ Day Count Convention                        │
#     │ Trade Status                                │
#     └─────────────────────────────────────────────┘
# ```
#
# Each attribute represents a business concept rather than a mathematical quantity.
#
# Together they define the economic identity of the transaction.

# %% [markdown]
# # Attribute Description
#
# | Attribute | Description |
# |------------|-------------|
# | Trade Identifier | Unique identifier assigned to the transaction. |
# | Counterparty | Legal entity participating in the agreement. |
# | Currency | Currency in which cashflows are exchanged. |
# | Notional | Principal amount used for coupon calculations. |
# | Fixed Rate | Contractual fixed interest rate. |
# | Floating Reference Index | Market benchmark for the floating leg. |
# | Pay / Receive Direction | Indicates the institution's payment obligation. |
# | Effective Date | Date on which the contract becomes active. |
# | Maturity Date | Contract termination date. |
# | Payment Frequency | Frequency of coupon exchanges. |
# | Day Count Convention | Convention used to calculate accrued interest. |
# | Trade Status | Current lifecycle state of the transaction. |

# %% [markdown]
# # Why an Object-Oriented Representation?
#
# Several approaches can be used to represent financial transactions in software.
#
# | Representation | Advantages | Limitations |
# |---------------|------------|-------------|
# | Individual Variables | Simple | Difficult to maintain as complexity increases |
# | Dictionary | Flexible | Limited validation and weak structure |
# | DataFrame | Suitable for portfolio analysis | Less appropriate for representing a single trade |
# | Class | Encapsulates data and behaviour | Requires additional implementation effort |
#
# Since this project focuses on building reusable analytical components, an object-oriented representation provides the most suitable foundation.
#
# The trade object developed in this notebook will later be extended with pricing results, cashflow schedules, sensitivity measures and valuation adjustments without changing its fundamental structure.

# %%
from dataclasses import dataclass
from datetime import date

# %% [markdown]
# # Why `@dataclass`?
#
# The trade object primarily stores structured business information.
#
# Python's `@dataclass` decorator is well suited for such objects because it automatically generates initialization, object representation and comparison methods while keeping the implementation concise.
#
# At this stage, the object acts as a business record rather than an analytical model.
#
# As additional functionality such as cashflow generation, pricing and sensitivity analysis is introduced, the implementation will gradually evolve to include domain-specific behaviour.

# %%
@dataclass
class InterestRateSwap:
    """
    Represents the contractual terms of a vanilla fixed-for-floating
    Interest Rate Swap.
    """

    trade_id: str
    counterparty: str

    currency: str

    notional: float

    fixed_rate: float

    floating_index: str

    pay_fixed: bool

    effective_date: date

    maturity_date: date

    payment_frequency: str

    day_count_convention: str

    status: str

# %% [markdown]
# # Creating a Trade Instance
#
# A class definition describes the structure of a financial instrument.
#
# An object represents a specific transaction.
#
# The following example creates a five-year USD Interest Rate Swap between the institution and a hypothetical counterparty.

# %%
swap = InterestRateSwap(
    trade_id="IRS001",
    counterparty="ABC Bank",

    currency="USD",

    notional=10_000_000,

    fixed_rate=0.0425,

    floating_index="SOFR",

    pay_fixed=True,

    effective_date=date(2025, 1, 15),

    maturity_date=date(2030, 1, 15),

    payment_frequency="Semi-Annual",

    day_count_convention="ACT/360",

    status="ACTIVE"
)

# %% [markdown]
# # Trade Validation
#
# Trade capture represents the first opportunity to verify the integrity of transaction data.
#
# Detecting invalid information during object creation is considerably less expensive than discovering errors after pricing, risk aggregation or regulatory reporting.
#
# The implementation therefore performs a small set of fundamental validation checks immediately after object creation.
#
# The initial validation rules focus on:
#
# - Positive notional amounts
# - Valid fixed interest rates
# - Chronological consistency of contract dates
# - Supported payment frequencies
# - Supported day count conventions
#
# Additional business rules will be introduced as the project evolves.

# %%
from dataclasses import dataclass
from datetime import date


@dataclass
class InterestRateSwap:
    """
    Represents the contractual terms of a vanilla fixed-for-floating
    Interest Rate Swap.
    """

    trade_id: str
    counterparty: str
    currency: str
    notional: float
    fixed_rate: float
    floating_index: str
    pay_fixed: bool
    effective_date: date
    maturity_date: date
    payment_frequency: str
    day_count_convention: str
    status: str

    def __post_init__(self):
        self._validate()

    def _validate(self):
        """Validate the business attributes of the trade."""

        if self.notional <= 0:
            raise ValueError("Notional amount must be positive.")

        if not 0 <= self.fixed_rate <= 1:
            raise ValueError(
                "Fixed rate must be expressed as a decimal between 0 and 1."
            )

        if self.effective_date >= self.maturity_date:
            raise ValueError(
                "Maturity date must be later than the effective date."
            )

        valid_frequencies = {
            "Monthly",
            "Quarterly",
            "Semi-Annual",
            "Annual",
        }

        if self.payment_frequency not in valid_frequencies:
            raise ValueError(
                f"Unsupported payment frequency: {self.payment_frequency}"
            )

        valid_day_counts = {
            "ACT/360",
            "ACT/365",
            "30/360",
        }

        if self.day_count_convention not in valid_day_counts:
            raise ValueError(
                f"Unsupported day count convention: {self.day_count_convention}"
            )
                 def trade_summary(self):
        """Display a formatted summary of the trade."""

        direction = "Pay Fixed" if self.pay_fixed else "Receive Fixed"

        print("=" * 60)
        print("INTEREST RATE SWAP")
        print("=" * 60)
        print(f"Trade ID            : {self.trade_id}")
        print(f"Counterparty        : {self.counterparty}")
        print(f"Currency            : {self.currency}")
        print(f"Notional            : {self.notional:,.0f}")
        print(f"Direction           : {direction}")
        print(f"Fixed Rate          : {self.fixed_rate:.4%}")
        print(f"Floating Index      : {self.floating_index}")
        print(f"Effective Date      : {self.effective_date}")
        print(f"Maturity Date       : {self.maturity_date}")
        print(f"Payment Frequency   : {self.payment_frequency}")
        print(f"Day Count           : {self.day_count_convention}")
        print(f"Status              : {self.status}")
        print("=" * 60)
# Out:
#   Cell In[12], line 66
#     def trade_summary(self):
#     ^
# IndentationError: unexpected indent

# %%
def __post_init__(self):
    print("Inside __post_init__")
    self._validate()

# %%
print(hasattr(InterestRateSwap, "_validate"))
# Out:
# True

# %% [markdown]
# # Validation in Practice
#
# Validation rules protect the integrity of downstream analytics.
#
# Without these checks, invalid trades may successfully pass through pricing and risk engines while producing economically meaningless results.
#
# Although the current implementation contains only a small number of rules, the underlying design allows additional business validation to be incorporated without modifying the external interface of the trade object.

# %%
swap = InterestRateSwap(
    trade_id="IRS001",
    counterparty="ABC Bank",
    currency="USD",
    notional=10_000_000,
    fixed_rate=0.0425,
    floating_index="SOFR",
    pay_fixed=True,
    effective_date=date(2025, 1, 15),
    maturity_date=date(2030, 1, 15),
    payment_frequency="Semi-Annual",
    day_count_convention="ACT/360",
    status="ACTIVE",
)

# %%
swap
# Out:
# InterestRateSwap(trade_id='IRS001', counterparty='ABC Bank', currency='USD', notional=10000000, fixed_rate=0.0425, floating_index='SOFR', pay_fixed=True, effective_date=datetime.date(2025, 1, 15), maturity_date=datetime.date(2030, 1, 15), payment_frequency='Semi-Annual', day_count_convention='ACT/360', status='ACTIVE')
